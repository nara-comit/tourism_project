# %%
1+1
import math

# %%
math.sin(3)
# Out:
# 0.1411200080598672

# %%
print(math.sqrt(4))
# Out:
# 2.0

# %%
station_names = [
    "Helsinki Harmaja",
    "Helsinki Kaisaniemi",
    "Helsinki Kaivopuisto",
    "Helsinki Kumpula",
]

# %%
len(station_names)
# Out:
# 4

# %%
station_names.reverse()

# %%
station_names
# Out:
# ['Helsinki Kumpula',
#  'Helsinki Kaivopuisto',
#  'Helsinki Kaisaniemi',
#  'Helsinki Harmaja']
